# %%
from sklearn import datasets, linear_model

# %%
diabetes = datasets.load_diabetes()

# %%
diabetes.data[2]
# Out:
# array([ 0.08529891,  0.05068012,  0.04445121, -0.00567061, -0.04559945,
#        -0.03419447, -0.03235593, -0.00259226,  0.00286377, -0.02593034])

# %%
diabetes.target.shape
# Out:
# (442,)

# %%
data['age']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-bdf3e9db6c24> in <module>
# ----> 1 data['age']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data = diabetes.data

# %%
target = diabetes.target

# %%
len(data[:,1])
# Out:
# 442

# %%
import numpy as np                                
import pandas as pd                               
import seaborn as sns                             
import matplotlib.pyplot as plt
from matplotlib import style
from mpl_toolkits.mplot3d import Axes3D

import pickle
from tqdm import tqdm_notebook as tqdm

# %matplotlib inline

# %%
def plotFeatures(cimport numpy as np                                
import pandas as pd                               
import seaborn as sns                             
import matplotlib.pyplot as plt
from matplotlib import style
from mpl_toolkits.mplot3d import Axes3D

import pickle
from tqdm import tqdm_notebook as tqdm

# %matplotlib inlineol_list,title):
    plt.figure(figsize=(10, 14))
    i = 0
    print(len(col_list))
    for col in col_list:
        i+=1
        plt.subplot(7,2,i)
        plt.plot(df[col],df["MEDV"],marker='.',linestyle='none')
        plt.title(title % (col))   
        plt.tight_layout()

# %%
plt.figure(figsize=(10, 10))
i = 0
for i in range(10):
    i+=1
    plt.subplot(7,2,i)
    plt.plot(data[:,i], target, marker='.', linestyle='none')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-b499bfe971e0> in <module>
#       4     i+=1
#       5     plt.subplot(7,2,i)
# ----> 6     plt.plot(data[:,i], target, marker='.', linestyle='none')
#
# IndexError: index 10 is out of bounds for axis 1 with size 10

# %%
plt.plot(data[:,7], target, marker='.', linestyle='none')

# %%
final = [data[2], data[8], target]

# %%
final[0]
# Out:
# array([ 0.08529891,  0.05068012,  0.04445121, -0.00567061, -0.04559945,
#        -0.03419447, -0.03235593, -0.00259226,  0.00286377, -0.02593034])

# %%
final = [data[:,2], data[:,8], target]

# %%
final = np.array(final)

# %%
final.T.shape
# Out:
# (442, 3)

# %%
final = final.T

# %%
final.shape
# Out:
# (442, 3)

# %%
final[0]
# Out:
# array([6.16962065e-02, 1.99084209e-02, 1.51000000e+02])

# %%
target =  a quantitative measure of disease progression one year after baseline

# %%
df = pd.DataFrame()

# %%
df["BMI"] = data[:,2]

# %%
df["blood serum measurement"] = data[:, 8]

# %%
df["target"] = target

# %%
df.head()
# Out:
#         BMI  blood serum measurement  target
# 0  0.061696                 0.019908   151.0
# 1 -0.051474                -0.068330    75.0
# 2  0.044451                 0.002864   141.0
# 3 -0.011595                 0.022692   206.0
# 4 -0.036385                -0.031991   135.0

# %%
df.to_csv("diabetes.csv")
